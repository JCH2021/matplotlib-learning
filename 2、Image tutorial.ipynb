# %%
import matplotlib.pyplot as plt
import matplotlib.image as mimg
import numpy as np

# %%
img = mimg.imread('girl.jpg')
plt.imshow(img)

# %%
imgr = img[:,:,0]
#只选取了第一通道颜色的图像
#可能和我们认识的红绿蓝有点差异
plt.imshow(imgr)

# %%
plt.imshow(img)
plt.colorbar()
#颜色对应像素值，色柱
plt.colorbar(orientation='horizontal')
#这个参数是增加水平色柱，默认是竖直方向的

# %%
plt.hist(img.ravel(), bins=256, range=(0.0, 1.0), fc='k', ec='k')
#颜色直方图，
#参数一的含义是将 numpy 数组展平成1维，即将所有的值放到一个1维的列表或数组中
# bins 的意思是直方图上柱子的个数
# range 可以理解为所有柱子在 x 方向上的长度范围
#最后两个参数我没弄明白
plt.show()
