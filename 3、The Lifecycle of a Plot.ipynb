# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
shenqibaobei = {
    'pen_huo_long':170, #喷火龙
    'lv_mao_chong':50, #绿毛虫
    'jia_he_ren_wa':210, #甲贺忍蛙
    'pi_ka_qiu':200, #皮卡丘
    'meng_huan':310, #梦幻
    'da_yan_she':110, #大岩蛇
    'geng_gui':210, #耿鬼
    'miao_miao':70 #喵喵
}
Pocket_Monster = list(shenqibaobei.keys())
Combat_power_value = list(shenqibaobei.values())
mean = np.mean(Combat_power_value)

# %%
fig, ax = plt.subplots()
ax.barh(Pocket_Monster,Combat_power_value)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
#将 x 轴标签进行45度旋转
ax.set(xlim=[0, 400], xlabel='Combat_power_value', ylabel='Pocket_Monster',
       title='shenqibaobei')
plt.show()
